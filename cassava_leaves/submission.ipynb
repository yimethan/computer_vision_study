# %%
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
import os

from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array, smart_resize

# %%
eff = load_model('../input/effnetb3/checkpoint_5.h5')

# %%
vgg = load_model('../input/vgg16-kfold/checkpoint_5.h5')

# %%
res = load_model('../input/resnet50/checkpoint_3.h5')

# %%
filenames = os.listdir('../input/cassava-leaf-disease-classification/test_images')

prediction = []

for image in filenames:
    img = load_img('../input/cassava-leaf-disease-classification/test_images/'+image)
    img = img_to_array(img)
    img = smart_resize(img, (300, 300))
    img = tf.reshape(img, (-1, 300, 300, 3))
    img = img / 255.
    vgg_pred = vgg.predict(img)
    eff_pred = eff.predict(img)
    res_pred = res.predict(img)
    pred = res_pred * 0.3 + eff_pred * 0.5 + vgg_pred * 0.2
    prediction.append(np.argmax(pred))

# %%
tf.keras.backend.clear_session()
del vgg
del eff
del res

# %%
my_submission = pd.DataFrame({'image_id': filenames, 'label': prediction})
my_submission.to_csv('submission.csv', index=False)

# %%
my_submission.head()
